# %%
questions=[
    ["What is the capital city of Nepal?", "Dharan", "Pokhara", "Butwal", "Kathmandu", 4],
    ["What is the capital city of Nepal?", "Dharan", "Pokhara", "Butwal", "Kathmandu", 4],
    ["What is the capital city of Nepal?", "Dharan", "Pokhara", "Butwal", "Kathmandu", 4],
    ["What is the capital city of Nepal?", "Dharan", "Pokhara", "Butwal", "Kathmandu", 4],
    ["What is the capital city of Nepal?", "Dharan", "Pokhara", "Butwal", "Kathmandu", 4],
    ["What is the capital city of Nepal?", "Dharan", "Pokhara", "Butwal", "Kathmandu", 4],
    ["What is the capital city of Nepal?", "Dharan", "Pokhara", "Butwal", "Kathmandu", 4],
    ["What is the capital city of Nepal?", "Dharan", "Pokhara", "Butwal", "Kathmandu", 4],
    ["What is the capital city of Nepal?", "Dharan", "Pokhara", "Butwal", "Kathmandu", 4],
    ["What is the capital city of Nepal?", "Dharan", "Pokhara", "Butwal", "Kathmandu", 4],
    ["What is the capital city of Nepal?", "Dharan", "Pokhara", "Butwal", "Kathmandu", 4],
    ["What is the capital city of Nepal?", "Dharan", "Pokhara", "Butwal", "Kathmandu", 4],
    ["What is the capital city of Nepal?", "Dharan", "Pokhara", "Butwal", "Kathmandu", 4],
    ["What is the capital city of Nepal?", "Dharan", "Pokhara", "Butwal", "Kathmandu", 4],
    ["What is the capital city of Nepal?", "Dharan", "Pokhara", "Butwal", "Kathmandu", 4],
    ["What is the capital city of Nepal?", "Dharan", "Pokhara", "Butwal", "Kathmandu", 4],
    ["What is the capital city of Nepal?", "Dharan", "Pokhara", "Butwal", "Kathmandu", 4],
    ["What is the capital city of Nepal?", "Dharan", "Pokhara", "Butwal", "Kathmandu", 4],
    ["What is the capital city of Nepal?", "Dharan", "Pokhara", "Butwal", "Kathmandu", 4],
    
]



levels=[1000, 2000, 3000, 5000, 10000, 20000, 40000, 80000, 160000, 320000]

money=0


for i in range(0, len(questions)):
    question= questions[i]
    
    
    print(f"\n\n questions for Rs. {levels[i]}")

    print(f"a. {question[1]}      b. {question[2]} ")

    print(f"c. {question[3]}      d. {question[4]} ")


    reply= int(input("Enter your reply (1-4) or 0 to quit\n:"))
    if(reply==0):
        money = levels[i-1]
        break
    
    if(reply==question[-1]):
        print(f"Correct Answer, You have won Rs. {levels[i]}")
    
        if(i == 4):
            money=10000
        
        elif(i == 9):
            money=320000
        
        elif(i == 14):
            money=1000000
    
    else:
        print("Wrong Answer!")
        break
    
    
print(f"Your take home money is RS. {money}")
# Out:
#  questions for Rs. 1000
# a. Dharan      b. Pokhara
# c. Butwal      d. Kathmandu
# Enter your reply (1-4) or 0 to quit
# :4
# Correct Answer, You have won Rs. 1000
#
#
#  questions for Rs. 2000
# a. Dharan      b. Pokhara
# c. Butwal      d. Kathmandu
# Enter your reply (1-4) or 0 to quit
# :4
# Correct Answer, You have won Rs. 2000
#
#
#  questions for Rs. 3000
# a. Dharan      b. Pokhara
# c. Butwal      d. Kathmandu
# Enter your reply (1-4) or 0 to quit
# :4
# Correct Answer, You have won Rs. 3000
#
#
#  questions for Rs. 5000
# a. Dharan      b. Pokhara
# c. Butwal      d. Kathmandu
# Enter your reply (1-4) or 0 to quit
# :4
# Correct Answer, You have won Rs. 5000
#
#
#  questions for Rs. 10000
# a. Dharan      b. Pokhara
# c. Butwal      d. Kathmandu
# Enter your reply (1-4) or 0 to quit
# :4
# Correct Answer, You have won Rs. 10000
#
#
#  questions for Rs. 20000
# a. Dharan      b. Pokhara
# c. Butwal      d. Kathmandu
# Enter your reply (1-4) or 0 to quit
# :2
# ...
